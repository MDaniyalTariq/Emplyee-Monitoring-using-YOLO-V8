# %% [markdown]
# <a href="https://colab.research.google.com/github/MDaniyalTariq/Emplyee-Monitoring-using-YOLO-V8/blob/main/human-action-recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nikhilkr31/human-action-recognition.git
# Out:
# Cloning into 'human-action-recognition'...
# remote: Enumerating objects: 35630, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 35630 (delta 18), reused 20 (delta 4), pack-reused 35586 (from 1)
# Receiving objects: 100% (35630/35630), 749.33 MiB | 1.17 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Updating files: 100% (36030/36030), done.

# %% [markdown]
# ## What is Human Action Recognition(HAR)?
#
# - Human activity recognition, or HAR for short, is a broad field of study concerned with identifying the specific movement or action of a person based on sensor data.
# - Movements are often typical activities performed indoors, such as walking, talking, standing, and sitting

# %% [markdown]
# ## Why it is important ?
# - Human activity recognition plays a significant role in human-to-human interaction and interpersonal relations.
# - Because it provides information about the identity of a person, their personality, and psychological state, it is difficult to extract.
# - The human ability to recognize another person’s activities is one of the main subjects of study of the scientific areas of computer vision and machine learning. As a result of this research, many applications, including video surveillance systems, human-computer interaction, and robotics for human behavior characterization, require a multiple activity recognition system.

# %% [markdown]
# ## Below are some practical applications of HAR:
#
# ![man boxing](https://github.com/nikhilkr31/human-action-recognition/blob/main/images/punching.gif?raw=1)
#
# Here we can see that the AI is able to identify what the man in the video is doing. This might raise the question of importance of identification of the action. Let's look at another example below:
#
# ![running in classroom](https://github.com/nikhilkr31/human-action-recognition/blob/main/images/har_run.gif?raw=1)
#
# Here we can see that the model is able to identify the troublesome student who is running in the classroom highlighted in red. Whereas the other kids who are walking normally are colored in green.
#
# This is a just small example of the endless applications that can help us automate monotonous and dangerous jobs.

# %% [markdown]
# ## What is a CNN?
#
# A convolutional neural network (CNN) is a type of artificial neural network used in image recognition and processing that is specifically designed to process pixel data.
#
# CNNs are powerful image processing, artificial intelligence (AI) that use deep learning to perform both generative and descriptive tasks, often using machine vison that includes image and video recognition, along with recommender systems and natural language processing (NLP).
#
# ![cnn](https://github.com/nikhilkr31/human-action-recognition/blob/main/images/cnn.jpeg?raw=1)
#
# ## VGG16
#
# VGG-16 is a convolutional neural network that is 16 layers deep. You can load a pretrained version of the network trained on more than a million images from the ImageNet database. The pretrained network can classify images into 1000 object categories, such as keyboard, mouse, pencil, and many animals. As a result, the network has learned rich feature representations for a wide range of images. The network has an image input size of 224-by-224.
#
# ![vgg16](https://github.com/nikhilkr31/human-action-recognition/blob/main/images/vgg16.png?raw=1)

# %% [markdown]
# ## What is Transfer Learning
#
# Transfer learning is a machine learning method where a model developed for a task is reused as the starting point for a model on a second task. It is a popular approach in deep learning where pre-trained models are used as the starting point on computer vision and natural language processing tasks given the vast compute and time resources required to develop neural network models on these problems and from the huge jumps in skill that they provide on related problems.
#
# ![transfer learning](https://github.com/nikhilkr31/human-action-recognition/blob/main/images/transfer.jpeg?raw=1)

# %% [markdown]
# ## HAR using Transfer Learning

# %% [markdown]
# ## Imports

# %%
import os
import glob

#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

#Scikit Learn
from sklearn.model_selection import train_test_split

#Image processing
import cv2 as cv

# tensorflow
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Activation, Dropout, Flatten, Dense
#Instead of from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator #Import from tensorflow.keras instead of just keras

# %%
#Dataframe classifying the actions
train_action = pd.read_csv("/content/human-action-recognition/data/Training_set.csv")
test_action = pd.read_csv("/content/human-action-recognition/data/Testing_set.csv")

# %%
train_action.head()
# Out:
#       filename         label
# 0  Image_1.jpg       sitting
# 1  Image_2.jpg  using_laptop
# 2  Image_3.jpg       hugging
# 3  Image_4.jpg      sleeping
# 4  Image_5.jpg  using_laptop

# %%
train_action.columns = ['filename', 'label']  # Assign correct column names
print(train_action.columns)  # Verify column names
# Out:
# Index(['filename', 'label'], dtype='object')

# %%
train_action.filename[0]
# Out:
# 'Image_1.jpg'

# %% [markdown]
# ## Looking at the data

# %%
#Printing the images along with their respective action

# Add a forward slash between 'train' and the filename
img = cv.imread('/content/human-action-recognition/data/train/' + train_action.filename[0])
plt.title(train_action.label[0])
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB));

# %%
test_action.shape
# Out:
# (5400, 1)

# %% [markdown]
# There are 12,600 images in the training dataset. Creating a function which will randomly sample a image from the set and print the image along with its labeled action.

# %%
#Sample images and their labels in the training data


def show_img_train():
    img_num = np.random.randint(0,12599)
    img = cv.imread('/content/human-action-recognition/data/train/' + train_action.filename[img_num])
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
    plt.title(train_action.label[img_num])

def show_img_test():
    img_num = np.random.randint(0,5399)
    img = cv.imread('/content/human-action-recognition/data/test/' + test_action.filename[img_num])
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_test()

# %%
show_img_test()

# %% [markdown]
# Note that the images from the test set do not contain the labels. That is for the model to predict.

# %% [markdown]
# ## Plotting the label classes

# %% [markdown]
# ### Pie chart

# %%
l = train_action.label.value_counts()
fig = px.pie(train_action, values=l.values, names=l.index, title='Distribution of Human Activity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c012663-7c0e-4968-b40d-022d90d27c30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c012663-7c0e-4968-b40d-022d90d27c30")) {                    Plotly.newPlot(                        "4c012663-7c0e-4968-b40d-022d90d27c30",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["sitting","using_laptop","hugging","sleeping","drinking","clapping","dancing","cycling","calling","laughing","eating","fighting","listening_to_music","running","texting"],"legendgroup":"","name":"","showlegend":true,"values":[840,840,840,840,840,840,840,840,840,840,840,840,840,840,840],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sca ...

# %% [markdown]
# ### Value counts

# %%
train_action.label.value_counts()
# Out:
# label
# sitting               840
# using_laptop          840
# hugging               840
# sleeping              840
# drinking              840
# clapping              840
# dancing               840
# cycling               840
# calling               840
# laughing              840
# eating                840
# fighting              840
# listening_to_music    840
# running               840
# texting               840
# Name: count, dtype: int64

# %% [markdown]
# The output classes for the image classification are balanced. This reduces a step in pre-processing which deals with imbalanced classes using techniques such as SMOTE, under-sampling, etc.

# %% [markdown]
# ## Preprocessing

# %%
img = cv.imread('/content/human-action-recognition/data/train/' + train_action.filename[0])

#OpenCV reads the images in BGR instead of the standard RGB, hence the below line of code

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB));
print(img.shape)
# Out:
# (160, 240, 3)

# %% [markdown]
# The inputs for VGG16 model as per the Tensorflow documentation is 224x224. Here out training set images come in all different sizes. We need to resize the images.

# %% [markdown]
# ### Create the directory for resized images

# %% [markdown]
# Skipping the below cell since the folder has already been created.

# %%
#create resized directory in the current project folder
parent_dir = os.getcwd()
directory = 'resized-train'
path = os.path.join(parent_dir, directory)
os.mkdir(path)
print('Created "resized-train" folder')
# Out:
# Created "resized-train" folder

# %% [markdown]
# ## Resize the training images

# %%
#dimensions
width = 224
height = 224
dim = (width, height)

#resizing all the images in the train folder
for i in np.arange(len(train_action.filename)):
    #read the filename from the dataframe
    filename = train_action.filename.iloc[i]
    #read the image from the train folder
    img = cv.imread('/content/human-action-recognition/data/train/' + filename)
    #resize the image
    resized = cv.resize(img, dim, interpolation = cv.INTER_AREA)
    #write the image in resized folder
    cv.imwrite('./resized-train/' + filename ,resized)

# %% [markdown]
# ## Resize the test set images

# %%
#create resized directory in the current project folder
parent_dir = os.getcwd()
directory = 'resized-test'
path = os.path.join(parent_dir, directory)
os.mkdir(path)
print('Created "resized-test" folder')
# Out:
# Created "resized-test" folder

# %%
#resizing all the images in the train folder
for i in np.arange(len(test_action.filename)):
    #read the filename from the dataframe
    filename = test_action.filename.iloc[i]
    #read the image from the train folder
    img = cv.imread('/content/human-action-recognition/data/test/' + filename)
    #resize the image
    resized = cv.resize(img, dim, interpolation = cv.INTER_AREA)
    #write the image in resized folder
    cv.imwrite('./resized-test/' + filename ,resized)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Display image

# %%
img = cv.imread('resized-train/' + train_action.filename[0])
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
print(img.shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# We can see that the images have been resized and stored in a different directory. This helps us avoid resizing the images everytime we run the notebook.

# %% [markdown]
# ## Read images and convert them into numpy arrays

# %% [markdown]
# ## X

# %%
#empty list train
X = []

#reading all the resized images
for i in np.arange(len(train_action.filename)):
    img = cv.imread('resized-train/' + train_action.filename[i])
    X.append(img)

X = np.asarray(X)
X.shape
# Out:
# (12600, 224, 224, 3)

# %% [markdown]
# ## y

# %%
y = np.asarray(pd.get_dummies(train_action.label))
print(y.shape)
# Out:
# (12600, 15)

# %% [markdown]
# ## Test train Split

# %%
print(X.shape,y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42,stratify=train_action.label)
# Out:
# (12600, 224, 224, 3) (12600, 15)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (11340, 224, 224, 3) (11340, 15)

# %% [markdown]
# ## Unseen test set
#
# This set of images are meant to be submitted on Kaggle. We wont be using this data for this project.

# %%
#empty list test
X_unseen = []

#reading all the resized images
for i in np.arange(len(test_action.filename)):
    img = cv.imread('resized-test/' + test_action.filename[i])
    X_unseen.append(img)

X_unseen = np.asarray(X_unseen)
X_unseen.shape
# Out:
# (5400, 224, 224, 3)

# %% [markdown]
# ## Building the CNN model using transfer learning

# %% [markdown]
# ### Initializing a VGG16 model

# %%
#Sequential model constructor
cnn_model = Sequential()

#initializing a vgg16 wihtout the top layers
pretrained_model= tf.keras.applications.VGG16(include_top=False,
                   input_shape=(224,224,3),
                   pooling='avg',classes=15,
                   weights='imagenet')

#Freezing the deeper layers
for layer in pretrained_model.layers:
        layer.trainable=False

#adding our layers to the model
cnn_model.add(pretrained_model)
cnn_model.add(Flatten())
cnn_model.add(Dense(512, activation='relu'))
cnn_model.add(Dense(15, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# ## Model Summary

# %% [markdown]
# - The loss function that we are trying to minimize is Categorical Cross Entropy. This metric is used in multiclass classification. This is used alongside softmax activation function.
#
# - Adam is an optimization algorithm that can be used instead of the classical stochastic gradient descent procedure to update network weights iterative based in training data. This algorithm is straight forward to implement and computationally efficient.

# %%
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 512)                 │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 15)                  │           7,695 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,985,039 (57.16 MB)
#  Trainable params: 270,351 (1.03 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## Training the model

# %%
history = cnn_model.fit(X_train,y_train, epochs=60)
# Out:
# Epoch 1/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 73s 168ms/step - accuracy: 0.4370 - loss: 2.6945
# Epoch 2/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 164ms/step - accuracy: 0.6864 - loss: 0.9781
# Epoch 3/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.7482 - loss: 0.7609
# Epoch 4/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.8198 - loss: 0.5535
# Epoch 5/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.8724 - loss: 0.4027
# Epoch 6/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9012 - loss: 0.2956
# Epoch 7/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9396 - loss: 0.2044
# Epoch 8/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9642 - loss: 0.1270
# Epoch 9/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9809 - loss: 0.0822
# Epoch 10/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9633 - loss: 0.1113
# Epoch 11/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9584 - loss: 0.1233
# Epoch 12/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9587 - loss: 0.1235
# Epoch 13/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9717 - loss: 0.0923
# Epoch 14/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9843 - loss: 0.0553
# Epoch 15/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9770 - loss: 0.0673
# Epoch 16/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9738 - loss: 0.0781
# Epoch 17/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9718 - loss: 0.0936
# Epoch 18/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9729 - loss: 0.0787
# Epoch 19/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9850 - loss: 0.0486
# Epoch 20/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9662 - loss: 0.1097
# Epoch 21/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9716 - loss: 0.0837
# Epoch 22/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9914 - loss: 0.0308
# Epoch 23/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9867 - loss: 0.0431
# Epoch 24/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9789 - loss: 0.0697
# Epoch 25/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9652 - loss: 0.1080
# Epoch 26/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9752 - loss: 0.0819
# Epoch 27/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9872 - loss: 0.0456
# Epoch 28/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9859 - loss: 0.0489
# Epoch 29/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9919 - loss: 0.0301
# Epoch 30/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9758 - loss: 0.0771
# Epoch 31/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9678 - loss: 0.1124
# Epoch 32/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9858 - loss: 0.0472
# Epoch 33/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9828 - loss: 0.0592
# Epoch 34/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9767 - loss: 0.0836
# Epoch 35/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9955 - loss: 0.0160
# Epoch 36/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9873 - loss: 0.0477
# Epoch 37/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9733 - loss: 0.0932
# Epoch 38/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9820 - loss: 0.0620
# Epoch 39/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9831 - loss: 0.0620
# Epoch 40/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9870 - loss: 0.0384
# Epoch 41/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9911 - loss: 0.0301
# Epoch 42/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9961 - loss: 0.0123
# Epoch 43/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9794 - loss: 0.0728
# Epoch 44/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9738 - loss: 0.0935
# Epoch 45/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9840 - loss: 0.0508
# Epoch 46/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9869 - loss: 0.0393
# Epoch 47/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9913 - loss: 0.0278
# Epoch 48/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9866 - loss: 0.0438
# Epoch 49/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9850 - loss: 0.0443
# Epoch 50/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9931 - loss: 0.0169
# Epoch 51/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 165ms/step - accuracy: 0.9908 - loss: 0.0345
# Epoch 52/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9799 - loss: 0.0812
# Epoch 53/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9862 - loss: 0.0506
# Epoch 54/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.9918 - loss: 0.0277
# Epoch 55/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9925 - loss: 0.0225
# Epoch 56/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9944 - loss: 0.0202
# Epoch 57/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9883 - loss: 0.0502
# Epoch 58/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.9888 - loss: 0.0324
# Epoch 59/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9871 - loss: 0.0399
# Epoch 60/60
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 58s 162ms/step - accuracy: 0.9803 - loss: 0.0766

# %% [markdown]
# ## Save the model weights

# %%
import os

# Create the 'model' directory if it doesn't exist
os.makedirs('./content/human-action-recognition/model', exist_ok=True)

# Now save the model weights
cnn_model.save_weights('./content/human-action-recognition/model/cnn_model.weights.h5')

# %%
cnn_model.save('./content/human-action-recognition/model/cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#Saving the trained weights
cnn_model.save_weights('./content/human-action-recognition/model/cnn_model.h5')

# %%
#plotting the loss
loss = history.history['loss']

plt.title("Loss Function")
plt.xlabel("epochs")
sns.set_theme(style='darkgrid')
sns.lineplot(loss);

# %%
plt.title("Accuracy")
plt.xlabel("epochs")
accu = history.history['accuracy']
sns.lineplot(accu);

# %% [markdown]
# ## Predictions

# %%
y_preds = cnn_model.predict(X_test)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step

# %% [markdown]
# ## Accuracy and Log Loss

# %%
from sklearn.metrics import accuracy_score, log_loss

print('Log Loss:',log_loss(np.round(y_preds),y_test))
print('Accuracy:',accuracy_score(np.round(y_preds),y_test))
# Out:
# Log Loss: 12.92994550149282
# Accuracy: 0.6333333333333333

# %% [markdown]
# ## Visualizing the predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mimg

# Mapping class indices to class names and numbers
class_names = {
    0: ("Sitting", 840),
    1: ("Using Laptop", 840),
    2: ("Hugging", 840),
    3: ("Sleeping", 840),
    4: ("Drinking", 840),
    5: ("Clapping", 840),
    6: ("Dancing", 840),
    7: ("Cycling", 840),
    8: ("Calling", 840),
    9: ("Laughing", 840),
    10: ("Eating", 840),
    11: ("Fighting", 840),
    12: ("Listening to Music", 840),
    13: ("Running", 840),
    14: ("Texting", 840)
}

# Reading and resizing the image
def read_image(fn):
    image = Image.open(fn)
    return np.asarray(image.resize((224, 224)))

# Predict the class and confidence of the prediction
def test_predict(test_image):
    result = cnn_model.predict(np.asarray([read_image(test_image)]))

    itemindex = np.argmax(result)  # Get the index of the highest probability
    confidence = np.max(result) * 100  # Convert to percentage

    class_name, class_number = class_names.get(itemindex, ("Unknown", "N/A"))  # Get class name and number
    print(f"Probability: {confidence:.2f}%\nPredicted Class: {itemindex} - {class_name} ({class_number})")

    # Display the image with class name, number, and probability
    image = mimg.imread(test_image)
    plt.imshow(image)
    plt.title(f"{itemindex} - {class_name} ({class_number}) ({confidence:.2f}%)")
    plt.axis("off")
    plt.show()

# %%
#Image 1
filename = test_action.filename.iloc[7]
test_predict('./resized-test/' + filename)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Probability: 97.23%
# Predicted Class: 9 - Laughing (840)

# %%
#Image 2
filename = test_action.filename.iloc[1]
test_predict('./resized-test/' + filename)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Probability: 99.86%
# Predicted Class: 11 - Fighting (840)

# %% [markdown]
# ## Next Steps and Recommendations
#
#
# - In order to improve the accuracy, we can unfreeze few more layers and retrain the model. This will help us further improve the model.
#
# - We can tune the parameters using KerasTuner.
#
# - The model reached a good accuracy score after the 20 epochs but it has been trained for 60 epochs. There is definitely some overfitting which can avoided with early stopping.
#
# - The nodes in the deep layers were connected. We can introduce some amount dropout for regularization.
